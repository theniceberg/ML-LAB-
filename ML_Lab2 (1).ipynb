# %% [markdown]
# # Name:-Rishabh Dwivedi
# Roll No:-45
# Section:-C
# Batch:-C3

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
#Step 1:Load dataset
df = pd.read_csv("USA_Housing.csv")

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
df.tail()
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 4995                          3.46     22837.361035  1.060194e+06
# 4996                          4.02     25616.115489  1.482618e+06
# 4997                          2.13     33266.145490  1.030730e+06
# 4998                          5.44     42625.620156  1.198657e+06
# 4999                          4.07     46501.283803  1.298950e+06
#
#                                                 Address
# 4995                   USNS Williams\nFPO AP 30153-7653
# ...

# %%
df.shape
# Out:
# (5000, 7)

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
df.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop("Address", axis=1, inplace=True)

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
#Multivariate Analysis
plt.figure(figsize=(10,8))

numeric_df = df.select_dtypes(include=['number'])

sns.heatmap(numeric_df.corr(),
            annot=True,
            cmap='inferno')
plt.show()

# %%
#Univariate Analysis
plt.figure(figsize=(6,4))
sns.histplot(df["Avg. Area Income"],bins=20, kde=True)

plt.title("Avg area income Distribution")
plt.show()

# %%
#Bivariate Ananlysis
sns.countplot(x="Avg. Area Income", hue="Price", data=df)

plt.title("Avg. Area Income vs Price")
plt.show()

# %%
#Outlier detection with the help of graph.
sns.boxplot(x=df["Price"])
plt.show()

# %%
#Code for outlier detection and removing outlier with IQR method

Q1 = df["Price"].quantile(0.25)
Q3 = df["Price"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR

df = df[(df["Price"] >= lower) & (df["Price"] <= upper)]

# %%
sns.boxplot(x=df["Price"])
plt.show()

# %%
#Outlier detection with the help of graph.
sns.boxplot(x=df["Avg. Area Income"])
plt.show()

# %%
#Code for outlier detection

Q1 = df["Avg. Area Income"].quantile(0.25)
Q3 = df["Avg. Area Income"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR

df = df[(df["Avg. Area Income"] >= lower) & (df["Avg. Area Income"] <= upper)]

# %%
sns.boxplot(x=df["Avg. Area Income"])
plt.show()

# %%
#Multivariate Analysis
plt.figure(figsize=(10,8))

numeric_df = df.select_dtypes(include=['number'])

sns.heatmap(numeric_df.corr(),
            annot=True,
            cmap='inferno')
plt.show()

# %%
x = df[['Avg. Area Income']]
y = df['Price']

# %%
# 90:10 is high risk split for training and testing
# 40:60 is not valid for training and testing
# 85:15 is valid for training and testing
# Accuracy is R2 score

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

slr_model = LinearRegression()
slr_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = slr_model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np

print("Simple Linear Regression Results")
print("-------------------------------")

print("MAE :",mean_absolute_error(y_test, y_pred))
print("MSE :",mean_squared_error(y_test, y_pred))
print("RMSE:",np.sqrt(mean_squared_error(y_test, y_pred)))
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# Simple Linear Regression Results
# -------------------------------
# MAE : 209409.3018216627
# MSE : 66978557287.983284
# RMSE: 258802.1585844741
# R2 Score: 0.42914402441550337

# %%
print("Intercept:", slr_model.intercept_)
print("Slope:", slr_model.coef_[0])
# Out:
# Intercept: -155455.2824973939
# Slope: 20.250537400684834

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_test,y_test,color='blue',label='Actual Data')
plt.plot(x_test,y_pred,color='red', linewidth=2,label='Regression Line')

plt.xlabel("Avg. Area Income")
plt.ylabel("House Price")
plt.title("Simple Linear Regression")
plt.legend()

plt.show()

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import Ridge
ridge = Ridge()
ridge.fit(x_train, y_train)
ridge_pred = ridge.predict(x_test)
print("Default Ridge R",r2_score(y_test,ridge_pred))
# Out:
# Default Ridge R 0.4291440244153475

# %%
param_grid = {'alpha':[0.001,0.01,0.1,1,10,100]}

# %%
grid_ridge = GridSearchCV(estimator=Ridge(),param_grid=param_grid,scoring = 'r2',cv=5)
grid_ridge.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1, 10, 100]},
#              scoring='r2')

# %%
best_ridge = grid_ridge.best_estimator_
ridge_pred = best_ridge.predict(x_test)
print("Best Ridge R",r2_score(y_test,ridge_pred))
# Out:
# Best Ridge R 0.4291440243999194

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

print("Ridge Regression Results")
print("-------------------------")

print("MAE :", mean_absolute_error(y_test, ridge_pred))
print("MSE :", mean_squared_error(y_test, ridge_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, ridge_pred)))
print("R2 Score:", r2_score(y_test, ridge_pred))
# Out:
# Ridge Regression Results
# -------------------------
# MAE : 209409.30182542087
# MSE : 66978557289.81176
# RMSE: 258802.15858800669
# R2 Score: 0.4291440243999194
